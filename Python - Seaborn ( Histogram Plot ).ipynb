# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df1=sns.load_dataset("tips")

# %%
data=px.data.gapminder()

# %%
df=data

# %%
df.head(3)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4

# %%
df.tail(3)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 1701      716
# 1702      716
# 1703      716

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap',
#        'iso_alpha', 'iso_num'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %% [markdown]
# # Distribution Plot:

# %% [markdown]
# Used for univariate analysis
#
# used for finding distribution
#
# range observation
#
# Central Tendancy
#
# Is the bimodal
#
# are there any outliers

# %% [markdown]
# #### There are three distribution plot:
#
# 1)Hisplot()
#
# 2)kdeplot()
#
# 3)rugplot()

# %% [markdown]
# figure level function: displot
#
# axes plot: hisplot,kdeplot,rugplot

# %%
sns.histplot(data=df1,x="total_bill")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data=df1,x="tip")
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap',
#        'iso_alpha', 'iso_num'],
#       dtype='object')

# %%
sns.histplot(data=df,x="lifeExp")
# Out:
# <Axes: xlabel='lifeExp', ylabel='Count'>

# %%
sns.histplot(data=df,x="gdpPercap")
# Out:
# <Axes: xlabel='gdpPercap', ylabel='Count'>

# %% [markdown]
# #### Displot:

# %%
sns.displot(data=df1,x="total_bill",kind="hist")
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=df,x="lifeExp",kind="hist")
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=df1,x="tip",kind="hist")
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=df1,x="total_bill",kind="hist",bins=20)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=df1,x="day",kind="hist",hue="smoker")
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df1.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.displot(data=df1,x="tip",hue="smoker",kind="hist")
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.histplot(data=df1,x="smoker",hue="sex")
# Out:
# <Axes: xlabel='smoker', ylabel='Count'>

# %%
sns.histplot(data=df1,x="tip",hue="smoker")
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# #### Step parameter : Outline of the bar

# %%
sns.displot(data=df1,x="total_bill",hue="smoker",kind="hist",element="step")
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
dft=sns.load_dataset("titanic")

# %%
dft.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
sns.histplot(data=dft,x="age",hue="sex")
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=dft,x="pclass",hue="survived")
# Out:
# <Axes: xlabel='pclass', ylabel='Count'>

# %%
sns.histplot(data=dft,x="fare",hue="class")
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.histplot(data=dft,x="class",hue="alive")
# Out:
# <Axes: xlabel='class', ylabel='Count'>

# %%
sns.histplot(data=dft,x="age",)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.displot(data=dft,x="age",col="sex",kind="hist")
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Hist function wont show to graph as its a axes level function
