# %% [markdown]
# ## Pandas Introduction :

# %% [markdown]
#  Pandas is a powerful and flexible Python library used for data manipulation and analysis. It's built on top of NumPy, providing high-performance data structures and data analysis tools

# %%
import pandas as pd

# %%
import pandas as pd
import numpy as np
import faker

# Initialize Faker
fake = faker.Faker()

# Number of rows
num_rows = 250

# Generating data
data = {
    'empid': [fake.unique.random_int(min=1000, max=9999) for _ in range(num_rows)],
    'empname': [fake.name() for _ in range(num_rows)],
    'joining_date': [fake.date_this_decade() for _ in range(num_rows)],
    'empcity': [fake.city() for _ in range(num_rows)]
}

# Create DataFrame
df = pd.DataFrame(data)

# Introduce 30% missing values
nan_indices = np.random.choice(df.index, size=int(num_rows * 0.3), replace=False)
for col in df.columns:
    df.loc[nan_indices, col] = np.nan

# Display the first 10 rows of the DataFrame
print(df.head(10))
# Out:
#     empid             empname joining_date      empcity
# 0     NaN                 NaN          NaN          NaN
# 1  2957.0      Brianna Jordan   2023-10-09   Pamelafort
# 2  2116.0  Rebecca Montgomery   2020-03-31  Johnnyville
# 3  2577.0     Judith Mitchell   2021-02-09    Ochoaview
# 4  6632.0           Mary Love   2020-11-13  New Jessica
# 5  9613.0         Daniel Rowe   2023-08-15  Hallchester
# 6     NaN                 NaN          NaN          NaN
# 7  2035.0         John Miller   2023-03-18   West David
# 8  3513.0           Kyle Wise   2023-11-09  North Emily
# 9  9615.0          Brian Kemp   2020-09-28     Lisaview

# %%
print(df.to_string())
# Out:
#       empid                       empname joining_date                 empcity
# 0       NaN                           NaN          NaN                     NaN
# 1       NaN                           NaN          NaN                     NaN
# 2    1362.0                      Brad Day   2024-02-13              Walkertown
# 3    7314.0               Theresa Jackson   2022-05-21          West Caseystad
# 4       NaN                           NaN          NaN                     NaN
# 5    3872.0                     Lisa Lowe   2022-03-24       New Christinaport
# 6    2154.0                  Jeffrey Gill   2023-04-25              East Sarah
# 7    8600.0                 Rebecca Brown   2020-09-23      South Davidchester
# 8    9459.0                 Hector Juarez   2022-05-20              Julianbury
# 9    2881.0                  Julia Wilson   2023-11-14              Ramosshire
# 10   9037.0               Joshua Guerrero   2023-05-23               Moyerberg
# 11      NaN                           NaN          NaN                     NaN
# 12   8495.0               Kimberly Bryant   2020-01-25              Amandabury
# 13   8041.0                   Eric Potter   2021-10-05            East Jessica
# 14      NaN                           NaN          NaN                     NaN
# 15   7541.0                  Emily Larsen   2020-03-21            New Johnberg
# 16      NaN                           NaN          NaN                     NaN
# 17   3816.0              Jennifer Cabrera   2021-08-10             Parrishport
# 18   8037.0                Katherine Snow   2022-01-04      New Christopherton
# 19   2012.0               Monique Fischer   2020-01-04            North Nathan
# 20   5098.0               Krista Anderson   2023-09-14          New Leslieberg
# 21      NaN                           NaN          NaN                     NaN
# 22   8564.0                   Isaac Avila   2021-10-09            Cynthiaburgh
# 23   1410.0                      Todd Cox   2021-08-26          Burgessborough
# 24   6053.0               Kimberly Phelps   2022-04-23               Lake Erin
# 25   4754.0                  Lisa Andrade   2020-09-11               Kellerton
# 26   3303.0                     Joel Ward   2020-07-14        South Thomasberg
# 244     NaN                           NaN          NaN                     NaN
# 245  2103.0                  Danny Larson   2021-12-27                 Fryland
# 246  2605.0                Stacy Gonzalez   2023-02-22       East Victoriatown
# 247  9967.0                   Nathan Hull   2023-03-03              Torresview
# 248  2445.0              Benjamin Johnson   2022-09-03             Feliciafort
# 249  2376.0                 Jeffery Barry   2024-02-18       South Michaelstad

# %%
# Creating a DataFrame
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 24, 35, 32],
    'City': ['New York', 'Paris', 'Berlin', 'London']
}
df1 = pd.DataFrame(data)
print(df1)
# Out:
#     Name  Age      City
# 0   John   28  New York
# 1   Anna   24     Paris
# 2  Peter   35    Berlin
# 3  Linda   32    London

# %% [markdown]
# # Basic Operation in pandas

# %% [markdown]
# ### Viewing Data:
# head(n): Returns the first n rows.
#
# tail(n): Returns the last n rows.
#
# info(): Provides a summary of the DataFrame.
#
# describe(): Generates descriptive statistics.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   empid         175 non-null    float64
#  1   empname       175 non-null    object
#  2   joining_date  175 non-null    object
#  3   empcity       175 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 7.9+ KB

# %%
df.head()
# Out:
#     empid          empname joining_date         empcity
# 0     NaN              NaN          NaN             NaN
# 1     NaN              NaN          NaN             NaN
# 2  1362.0         Brad Day   2024-02-13      Walkertown
# 3  7314.0  Theresa Jackson   2022-05-21  West Caseystad
# 4     NaN              NaN          NaN             NaN

# %%
df.head(6)# parameterize head
# Out:
#     empid          empname joining_date            empcity
# 0     NaN              NaN          NaN                NaN
# 1     NaN              NaN          NaN                NaN
# 2  1362.0         Brad Day   2024-02-13         Walkertown
# 3  7314.0  Theresa Jackson   2022-05-21     West Caseystad
# 4     NaN              NaN          NaN                NaN
# 5  3872.0        Lisa Lowe   2022-03-24  New Christinaport

# %%
df.tail()
# Out:
#       empid           empname joining_date            empcity
# 245  2103.0      Danny Larson   2021-12-27            Fryland
# 246  2605.0    Stacy Gonzalez   2023-02-22  East Victoriatown
# 247  9967.0       Nathan Hull   2023-03-03         Torresview
# 248  2445.0  Benjamin Johnson   2022-09-03        Feliciafort
# 249  2376.0     Jeffery Barry   2024-02-18  South Michaelstad

# %%
df.tail(6)#parameterize tail
# Out:
#       empid           empname joining_date            empcity
# 244     NaN               NaN          NaN                NaN
# 245  2103.0      Danny Larson   2021-12-27            Fryland
# 246  2605.0    Stacy Gonzalez   2023-02-22  East Victoriatown
# 247  9967.0       Nathan Hull   2023-03-03         Torresview
# 248  2445.0  Benjamin Johnson   2022-09-03        Feliciafort
# 249  2376.0     Jeffery Barry   2024-02-18  South Michaelstad

# %% [markdown]
# ### Indexing and Selecting Data
# Selecting a Column
#
# You can select a column as a Series:

# %%
print(df[["empid","empcity"]])
# Out:
#       empid            empcity
# 0       NaN                NaN
# 1       NaN                NaN
# 2    1362.0         Walkertown
# 3    7314.0     West Caseystad
# 4       NaN                NaN
# ..      ...                ...
# 245  2103.0            Fryland
# 246  2605.0  East Victoriatown
# 247  9967.0         Torresview
# 248  2445.0        Feliciafort
# 249  2376.0  South Michaelstad
#
# [250 rows x 2 columns]

# %%
print(df[["empid","empcity"]])
# Out:
#       empid            empcity
# 0       NaN                NaN
# 1       NaN                NaN
# 2    1362.0         Walkertown
# 3    7314.0     West Caseystad
# 4       NaN                NaN
# ..      ...                ...
# 245  2103.0            Fryland
# 246  2605.0  East Victoriatown
# 247  9967.0         Torresview
# 248  2445.0        Feliciafort
# 249  2376.0  South Michaelstad
#
# [250 rows x 2 columns]

# %% [markdown]
# ### Selecting Rows:
# iloc[]: Purely integer-location based indexing for selection by position.
#
# loc[]: Access a group of rows and columns by labels or a boolean array.

# %%
df["empid"].iloc[1]
# Out:
# nan

# %%
df["empid"].iloc[2]
# Out:
# 1362.0

# %%
df["empcity"].iloc[2]
# Out:
# 'Walkertown'

# %%
df["empcity"].iloc[3]
# Out:
# 'West Caseystad'

# %%
df['empid'].loc[2]
# Out:
# 1362.0

# %%
df["empcity"].loc[3]
# Out:
# 'West Caseystad'

# %% [markdown]
# ### Selecting Multiple Columns
# You can select multiple columns by passing a list of column names:

# %%
 print(df[["empid","empcity"]].to_string())

# %% [markdown]
# # Data Manipulation
# Adding a New Column
#
# You can add a new column by assigning a Series to a new column name:

# %%
df1["empsalary"]=[1,2,3,4]

# %%
df1
# Out:
#     Name  Age      City  empsalary
# 0   John   28  New York          1
# 1   Anna   24     Paris          2
# 2  Peter   35    Berlin          3
# 3  Linda   32    London          4

# %%
df1=df1.drop("empsalary",axis=1)

# %%
df1
# Out:
#     Name  Age      City
# 0   John   28  New York
# 1   Anna   24     Paris
# 2  Peter   35    Berlin
# 3  Linda   32    London

# %%
adults=df1[df1["Age"]>25]#Filteration of data
print(adults)
# Out:
#     Name  Age      City
# 0   John   28  New York
# 2  Peter   35    Berlin
# 3  Linda   32    London

# %%
adults=df1[df1["Name"]=="John"]
print(adults)
# Out:
#    Name  Age      City
# 0  John   28  New York

# %% [markdown]
# ### Handling Missing Data
# Pandas provides several methods to handle missing data:
#
# isnull(): Detect missing values.
#
# dropna(): Remove missing values.
#
# fillna(): Fill missing values.

# %%
df.isnull()
# Out:
#      empid  empname  joining_date  empcity
# 0     True     True          True     True
# 1     True     True          True     True
# 2    False    False         False    False
# 3    False    False         False    False
# 4     True     True          True     True
# ..     ...      ...           ...      ...
# 245  False    False         False    False
# 246  False    False         False    False
# 247  False    False         False    False
# 248  False    False         False    False
# 249  False    False         False    False
#
# [250 rows x 4 columns]

# %%
df.isna().sum()
# Out:
# empid           75
# empname         75
# joining_date    75
# empcity         75
# dtype: int64

# %%
df1.loc[1, 'Age'] = None  # Introducing a missing value
df1 = df1.dropna()  # Drop rows with missing values
print(df1)

# Fill missing values
df1['Age'].fillna(df1['Age'].mean(), inplace=True)
print(df1)
# Out:
#     Name   Age      City
# 0   John  28.0  New York
# 2  Peter  35.0    Berlin
# 3  Linda  32.0    London
#     Name   Age      City
# 0   John  28.0  New York
# 2  Peter  35.0    Berlin
# 3  Linda  32.0    London

# %%
import pandas as pd
import numpy as np
import faker

# Initialize Faker
fake = faker.Faker()

# Number of rows
num_rows = 250

# Generating data
data = {
    'empid': [fake.unique.random_int(min=1000, max=9999) for _ in range(num_rows)],
    'empname': [fake.name() for _ in range(num_rows)],
    'joining_date': [fake.date_this_decade() for _ in range(num_rows)],
    'empcity': [fake.city() for _ in range(num_rows)]
}

# Create DataFrame
df = pd.DataFrame(data)

# Introduce 30% missing values
nan_indices = np.random.choice(df.index, size=int(num_rows * 0.3), replace=False)
for col in df.columns:
    df.loc[nan_indices, col] = np.nan

# Display the first 10 rows of the DataFrame
print(df.head(10))
# Out:
#     empid           empname joining_date          empcity
# 0  3717.0      Jenna Jensen   2020-05-15      Weaverhaven
# 1     NaN               NaN          NaN              NaN
# 2     NaN               NaN          NaN              NaN
# 3     NaN               NaN          NaN              NaN
# 4  8667.0     John Phillips   2021-02-03      New Brandon
# 5  8688.0   Nathan Mccarthy   2021-05-21  New Patrickstad
# 6  8349.0  Brandon Richards   2021-12-27      Lake Alicia
# 7  5104.0         Ryan Shaw   2020-08-10       Smithville
# 8  5171.0    Jennifer Brown   2022-10-03   Carpentermouth
# 9  5779.0  Courtney Elliott   2020-09-05   Michaelborough

# %%
df
# Out:
#       empid           empname joining_date            empcity
# 0    3717.0      Jenna Jensen   2020-05-15        Weaverhaven
# 1       NaN               NaN          NaN                NaN
# 2       NaN               NaN          NaN                NaN
# 3       NaN               NaN          NaN                NaN
# 4    8667.0     John Phillips   2021-02-03        New Brandon
# ..      ...               ...          ...                ...
# 245  2280.0    Marc Rasmussen   2020-02-25         Fisherbury
# 246  1577.0     Scott Herrera   2021-08-03  North Caitlinside
# 247  5651.0  Stephen Robinson   2021-03-04          Tinahaven
# 248  6412.0   Denise Bradford   2020-04-29         Barrettton
# 249  9656.0   Margaret Harris   2022-05-07    Port Jacqueline
#
# [250 rows x 4 columns]

# %% [markdown]
# ### Viewing of Data

# %%
df.head()
# Out:
#     empid        empname joining_date      empcity
# 0  3717.0   Jenna Jensen   2020-05-15  Weaverhaven
# 1     NaN            NaN          NaN          NaN
# 2     NaN            NaN          NaN          NaN
# 3     NaN            NaN          NaN          NaN
# 4  8667.0  John Phillips   2021-02-03  New Brandon

# %%
df.head(3)#parameterized
# Out:
#     empid       empname joining_date      empcity
# 0  3717.0  Jenna Jensen   2020-05-15  Weaverhaven
# 1     NaN           NaN          NaN          NaN
# 2     NaN           NaN          NaN          NaN

# %%
# Generating descriptive statistics
print(df.describe(include='all'))
# Out:
#               empid       empname joining_date      empcity
# count    175.000000           175          175          175
# unique          NaN           175          167          175
# top             NaN  Jenna Jensen   2023-08-12  Weaverhaven
# freq            NaN             1            2            1
# mean    5580.508571           NaN          NaN          NaN
# std     2545.019172           NaN          NaN          NaN
# min     1018.000000           NaN          NaN          NaN
# 25%     3464.000000           NaN          NaN          NaN
# 50%     5592.000000           NaN          NaN          NaN
# 75%     7730.000000           NaN          NaN          NaN
# max     9985.000000           NaN          NaN          NaN

# %%
print(df["empid"].head())
# Out:
# 0    3717.0
# 1       NaN
# 2       NaN
# 3       NaN
# 4    8667.0
# Name: empid, dtype: float64

# %%
print(df["empname"].tail())
# Out:
# 245      Marc Rasmussen
# 246       Scott Herrera
# 247    Stephen Robinson
# 248     Denise Bradford
# 249     Margaret Harris
# Name: empname, dtype: object

# %%
print(df[["empid","empcity"]].head())
# Out:
#     empid      empcity
# 0  3717.0  Weaverhaven
# 1     NaN          NaN
# 2     NaN          NaN
# 3     NaN          NaN
# 4  8667.0  New Brandon

# %%
print(df[["joining_date","empname"]].tail())
# Out:
#     joining_date           empname
# 245   2020-02-25    Marc Rasmussen
# 246   2021-08-03     Scott Herrera
# 247   2021-03-04  Stephen Robinson
# 248   2020-04-29   Denise Bradford
# 249   2022-05-07   Margaret Harris

# %%
df.loc[0:5]
# Out:
#     empid          empname joining_date          empcity
# 0  3717.0     Jenna Jensen   2020-05-15      Weaverhaven
# 1     NaN              NaN          NaN              NaN
# 2     NaN              NaN          NaN              NaN
# 3     NaN              NaN          NaN              NaN
# 4  8667.0    John Phillips   2021-02-03      New Brandon
# 5  8688.0  Nathan Mccarthy   2021-05-21  New Patrickstad

# %%
df.loc[12:15]# gives one less value so always give extra value
# Out:
#      empid      empname joining_date           empcity
# 12     NaN          NaN          NaN               NaN
# 13  6567.0   Frank Hall   2024-02-11         Scotttown
# 14  4884.0  Brian Boone   2024-05-03  West Selenaburgh
# 15     NaN          NaN          NaN               NaN

# %%
df.iloc[12:18]
# Out:
#      empid           empname joining_date           empcity
# 12     NaN               NaN          NaN               NaN
# 13  6567.0        Frank Hall   2024-02-11         Scotttown
# 14  4884.0       Brian Boone   2024-05-03  West Selenaburgh
# 15     NaN               NaN          NaN               NaN
# 16  6514.0      Gary Lindsey   2024-02-20        Clarkhaven
# 17  9713.0  Thomas Schneider   2022-04-08    New Sandrafort

# %%
df['salary'] = np.random.randint(30000, 120000, size=num_rows)

# %%
df
# Out:
#       empid           empname joining_date            empcity  salary
# 0    3717.0      Jenna Jensen   2020-05-15        Weaverhaven   47213
# 1       NaN               NaN          NaN                NaN  111092
# 2       NaN               NaN          NaN                NaN  101775
# 3       NaN               NaN          NaN                NaN   52193
# 4    8667.0     John Phillips   2021-02-03        New Brandon   71639
# ..      ...               ...          ...                ...     ...
# 245  2280.0    Marc Rasmussen   2020-02-25         Fisherbury   73575
# 246  1577.0     Scott Herrera   2021-08-03  North Caitlinside   79049
# 247  5651.0  Stephen Robinson   2021-03-04          Tinahaven  100891
# 248  6412.0   Denise Bradford   2020-04-29         Barrettton   67814
# 249  9656.0   Margaret Harris   2022-05-07    Port Jacqueline  103024
#
# [250 rows x 5 columns]

# %%
df["Bonus"]=np.random.randint(5000,7500,size=num_rows)

# %%
df
# Out:
#       empid           empname joining_date            empcity  salary  Bonus
# 0    3717.0      Jenna Jensen   2020-05-15        Weaverhaven   47213   7041
# 1       NaN               NaN          NaN                NaN  111092   5152
# 2       NaN               NaN          NaN                NaN  101775   5155
# 3       NaN               NaN          NaN                NaN   52193   6501
# 4    8667.0     John Phillips   2021-02-03        New Brandon   71639   5381
# ..      ...               ...          ...                ...     ...    ...
# 245  2280.0    Marc Rasmussen   2020-02-25         Fisherbury   73575   6201
# 246  1577.0     Scott Herrera   2021-08-03  North Caitlinside   79049   7419
# 247  5651.0  Stephen Robinson   2021-03-04          Tinahaven  100891   6808
# 248  6412.0   Denise Bradford   2020-04-29         Barrettton   67814   6062
# 249  9656.0   Margaret Harris   2022-05-07    Port Jacqueline  103024   5687
#
# [250 rows x 6 columns]

# %%
df=df.drop("salary",axis=1)

# %%
df
# Out:
#       empid           empname joining_date            empcity  Bonus
# 0    3717.0      Jenna Jensen   2020-05-15        Weaverhaven   7041
# 1       NaN               NaN          NaN                NaN   5152
# 2       NaN               NaN          NaN                NaN   5155
# 3       NaN               NaN          NaN                NaN   6501
# 4    8667.0     John Phillips   2021-02-03        New Brandon   5381
# ..      ...               ...          ...                ...    ...
# 245  2280.0    Marc Rasmussen   2020-02-25         Fisherbury   6201
# 246  1577.0     Scott Herrera   2021-08-03  North Caitlinside   7419
# 247  5651.0  Stephen Robinson   2021-03-04          Tinahaven   6808
# 248  6412.0   Denise Bradford   2020-04-29         Barrettton   6062
# 249  9656.0   Margaret Harris   2022-05-07    Port Jacqueline   5687
#
# [250 rows x 5 columns]

# %%
df=df.drop("Bonus",axis=1)

# %%
print(df)
# Out:
#       empid           empname joining_date            empcity
# 0    3717.0      Jenna Jensen   2020-05-15        Weaverhaven
# 1       NaN               NaN          NaN                NaN
# 2       NaN               NaN          NaN                NaN
# 3       NaN               NaN          NaN                NaN
# 4    8667.0     John Phillips   2021-02-03        New Brandon
# ..      ...               ...          ...                ...
# 245  2280.0    Marc Rasmussen   2020-02-25         Fisherbury
# 246  1577.0     Scott Herrera   2021-08-03  North Caitlinside
# 247  5651.0  Stephen Robinson   2021-03-04          Tinahaven
# 248  6412.0   Denise Bradford   2020-04-29         Barrettton
# 249  9656.0   Margaret Harris   2022-05-07    Port Jacqueline
#
# [250 rows x 4 columns]

# %%
print(df["empcity"].to_string())
# Out:
# 0               Weaverhaven
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4               New Brandon
# 5           New Patrickstad
# 6               Lake Alicia
# 7                Smithville
# 8            Carpentermouth
# 9            Michaelborough
# 10            Rodriguezland
# 11          Lake Bonnieport
# 12                      NaN
# 13                Scotttown
# 14         West Selenaburgh
# 15                      NaN
# 16               Clarkhaven
# 17           New Sandrafort
# 18               Lake Kevin
# 19                Jamesfort
# 20                New Angel
# 21             Lake Jessica
# 22                      NaN
# 23        Port Victorialand
# 24                East Alan
# 25                      NaN
# 26                Kevinbury
# 27                      NaN
# 28                      NaN
# 29                Whitestad
# 30                 Johnbury
# 31                Traviston
# 32                      NaN
# 33                      NaN
# 34          East Jacobhaven
# 35             Lake Brandon
# 36                      NaN
# 37               New George
# 38                Lorimouth
# 39                      NaN
# 40          North Donnaland
# 41        West Vincenthaven
# 42             West Crystal
# 43                      NaN
# 44           East Lindaside
# 45                      NaN
# 46              Jeanneshire
# 47             Samanthaview
# 48             Matthewville
# 49               Sarahburgh
# 50             Lake Melanie
# 51                      NaN
# 52                      NaN
# 53             Bradleymouth
# 54                      NaN
# 55     North Matthewchester
# 56        West Mariaborough
# 57                      NaN
# 58                      NaN
# 59              Petersonton
# 60               Michaelton
# 61                      NaN
# 62              Castroburgh
# 63              Annettestad
# 64                      NaN
# 65               Rogersside
# 66             Davidchester
# 67                      NaN
# 68              Johnsonport
# 69                 Jameston
# 70                      NaN
# 71        East Abigailburgh
# 72       Lake Samanthamouth
# 73           Goodmanchester
# 74                      NaN
# 75                      NaN
# 76               Karenmouth
# 77                      NaN
# 78              East Samuel
# 79              Ericborough
# 80            Robertchester
# 81               Bradyhaven
# 82               New Lauren
# 83             Lake Amyside
# 84             Port Melissa
# 85               Stevenport
# 86                      NaN
# 87               Reginaview
# 88                Jamiebury
# 89         South Madisonton
# 90             Anthonymouth
# 91               North Joan
# 92                      NaN
# 93       Port Andrewchester
# 94             East Shannon
# 95         South Jacqueline
# 96            New Elizabeth
# 97               Kelseyside
# 98           East Elizabeth
# 99               Murraybury
# 100       West Michaelburgh
# 101             East Curtis
# 102             Sherryville
# 103             Port Hector
# 104             Lake Lauren
# 105              Samuelberg
# 106                     NaN
# 107                     NaN
# 108               East Tina
# 109                     NaN
# 110                     NaN
# 111           Port Danielle
# 112                     NaN
# 113                     NaN
# 114             Thorntonton
# 115           Lake Lisaview
# 116      East Christinafurt
# 117            Port Matthew
# 118               Leahhaven
# 119         Lake Nancyburgh
# 120              Greeneside
# 121                     NaN
# 122                     NaN
# 123                     NaN
# 124                     NaN
# 125              Smithhaven
# 126            Benjaminside
# 127                     NaN
# 128                 Hallton
# 129                     NaN
# 130             Wilsonshire
# 131              Brianafurt
# 132                     NaN
# 133             Pollardbury
# 134             Dennisburgh
# 135                     NaN
# 136            Thompsontown
# 137                     NaN
# 138              Palmerbury
# 139        East Michaeltown
# 140                     NaN
# 141              Olsonville
# 142                Jimmouth
# 143          Lake Jimmyfurt
# 144        West Kennethstad
# 145                     NaN
# 146              Kellyville
# 147           Lake Aaronton
# 148                     NaN
# 149              Turnerport
# 150          South Johnview
# 151                Loriberg
# 152               North Sue
# 153                     NaN
# 154                     NaN
# 155          New Bonnieview
# 156                     NaN
# 157      South Kimberlyfort
# 158            Jenniferberg
# 159            Jessicahaven
# 160             Port Joseph
# 161              Nicolestad
# 162              New Sandra
# 163            South Daniel
# 164                 Linstad
# 165               Clinebury
# 166     South Deniseborough
# 167             Fostermouth
# 168                     NaN
# 169                     NaN
# 170             Osborneview
# 171               Toddburgh
# 172              Jeremyside
# 173             Fuentesview
# 174             West Daniel
# 175              Sanchezton
# 176             Mcdonaldton
# 177                     NaN
# 178                 Diazton
# 179                     NaN
# 180              Edwardstad
# 181                     NaN
# 182                Susanton
# 183            North Leslie
# 184             East Morgan
# 185               Maryshire
# 186            Guerrerofort
# 187             Wrightshire
# 188        West Ericborough
# 189      East Jeremyborough
# 190            Mcdanielside
# 191                     NaN
# 192             North Dylan
# 193             Patricktown
# 194                     NaN
# 195                     NaN
# 196                     NaN
# 197                     NaN
# 198         Port Vickieberg
# 199                     NaN
# 200                     NaN
# 201                     NaN
# 202            Jacksonburgh
# 203                     NaN
# 204                     NaN
# 205             Heatherfort
# 206              Curryhaven
# 207                Hillberg
# 208                     NaN
# 209              Dianeville
# 210         Port Pamelaberg
# 211              Lake Katie
# 212      East Brandiborough
# 213                     NaN
# 214            Charlesville
# 215             Timothystad
# 216           Nicoleborough
# 217         Lake Jameshaven
# 218            West Kristen
# 219         North Markmouth
# 220       South Michaelfort
# 221           Gonzalezmouth
# 222               Smithside
# 223                     NaN
# 224              Brooksport
# 225               Lake Jodi
# 226            Jonathantown
# 227                     NaN
# 228                     NaN
# 229     South Joshuachester
# 230           Kimberlyburgh
# 231            Williamshire
# 232        Christopherville
# 233          Port Brianside
# 234                     NaN
# 235             South Scott
# 236                     NaN
# 237                     NaN
# 238             Kennethstad
# 239                     NaN
# 240          Johnsonborough
# 241                     NaN
# 242                Alanfort
# 243              Ibarratown
# 244              Knightport
# 245              Fisherbury
# 246       North Caitlinside
# 247               Tinahaven
# 248              Barrettton
# 249         Port Jacqueline

# %%
fdf=df[df["empcity"]=="Edwardstad"]

# %%
fdf
# Out:
#       empid         empname joining_date     empcity
# 180  4453.0  Cynthia Santos   2023-05-10  Edwardstad

# %%
fdf1=df[df["empcity"]=="Diazton"]
fdf1
# Out:
#       empid        empname joining_date  empcity
# 178  8148.0  Samuel Wright   2023-07-23  Diazton

# %%
df.isnull().sum()
# Out:
# empid           75
# empname         75
# joining_date    75
# empcity         75
# dtype: int64

# %%
df.dropna()
# Out:
#       empid           empname joining_date            empcity
# 0    3717.0      Jenna Jensen   2020-05-15        Weaverhaven
# 4    8667.0     John Phillips   2021-02-03        New Brandon
# 5    8688.0   Nathan Mccarthy   2021-05-21    New Patrickstad
# 6    8349.0  Brandon Richards   2021-12-27        Lake Alicia
# 7    5104.0         Ryan Shaw   2020-08-10         Smithville
# ..      ...               ...          ...                ...
# 245  2280.0    Marc Rasmussen   2020-02-25         Fisherbury
# 246  1577.0     Scott Herrera   2021-08-03  North Caitlinside
# 247  5651.0  Stephen Robinson   2021-03-04          Tinahaven
# 248  6412.0   Denise Bradford   2020-04-29         Barrettton
# 249  9656.0   Margaret Harris   2022-05-07    Port Jacqueline
#
# [175 rows x 4 columns]

# %%
df
# Out:
#       empid             empname joining_date           empcity
# 0       NaN                 NaN          NaN               NaN
# 1    2957.0      Brianna Jordan   2023-10-09        Pamelafort
# 2    2116.0  Rebecca Montgomery   2020-03-31       Johnnyville
# 3    2577.0     Judith Mitchell   2021-02-09         Ochoaview
# 4    6632.0           Mary Love   2020-11-13       New Jessica
# ..      ...                 ...          ...               ...
# 245  9433.0        David Campos   2022-04-24  Rodriguezborough
# 246  2787.0        Derek Jarvis   2024-04-27        Laurietown
# 247     NaN                 NaN          NaN               NaN
# 248  5223.0         Patty Greer   2020-03-02          Carrstad
# 249  9533.0        Matthew Hall   2024-05-23  North Carrieport
#
# [250 rows x 4 columns]

# %%
df.fillna("unknown",inplace=True)

# %%
df
# Out:
#        empid             empname joining_date           empcity
# 0    unknowm             unknowm      unknowm           unknowm
# 1     2957.0      Brianna Jordan   2023-10-09        Pamelafort
# 2     2116.0  Rebecca Montgomery   2020-03-31       Johnnyville
# 3     2577.0     Judith Mitchell   2021-02-09         Ochoaview
# 4     6632.0           Mary Love   2020-11-13       New Jessica
# ..       ...                 ...          ...               ...
# 245   9433.0        David Campos   2022-04-24  Rodriguezborough
# 246   2787.0        Derek Jarvis   2024-04-27        Laurietown
# 247  unknowm             unknowm      unknowm           unknowm
# 248   5223.0         Patty Greer   2020-03-02          Carrstad
# 249   9533.0        Matthew Hall   2024-05-23  North Carrieport
#
# [250 rows x 4 columns]

# %%
null_id_rows = df['empid'].isnull()

# %%
serial_numbers = range(1, null_id_rows.sum() + 1)

# %%
df.loc[null_id_rows, 'empid'] = serial_numbers

# %%
df
# Out:
#        empid             empname joining_date           empcity  id
# 0    unknowm             unknowm      unknowm           unknowm NaN
# 1     2957.0      Brianna Jordan   2023-10-09        Pamelafort NaN
# 2     2116.0  Rebecca Montgomery   2020-03-31       Johnnyville NaN
# 3     2577.0     Judith Mitchell   2021-02-09         Ochoaview NaN
# 4     6632.0           Mary Love   2020-11-13       New Jessica NaN
# ..       ...                 ...          ...               ...  ..
# 245   9433.0        David Campos   2022-04-24  Rodriguezborough NaN
# 246   2787.0        Derek Jarvis   2024-04-27        Laurietown NaN
# 247  unknowm             unknowm      unknowm           unknowm NaN
# 248   5223.0         Patty Greer   2020-03-02          Carrstad NaN
# 249   9533.0        Matthew Hall   2024-05-23  North Carrieport NaN
#
# [250 rows x 5 columns]

# %%
df.drop("id",axis=1)
# Out:
#        empid             empname joining_date           empcity
# 0    unknowm             unknowm      unknowm           unknowm
# 1     2957.0      Brianna Jordan   2023-10-09        Pamelafort
# 2     2116.0  Rebecca Montgomery   2020-03-31       Johnnyville
# 3     2577.0     Judith Mitchell   2021-02-09         Ochoaview
# 4     6632.0           Mary Love   2020-11-13       New Jessica
# ..       ...                 ...          ...               ...
# 245   9433.0        David Campos   2022-04-24  Rodriguezborough
# 246   2787.0        Derek Jarvis   2024-04-27        Laurietown
# 247  unknowm             unknowm      unknowm           unknowm
# 248   5223.0         Patty Greer   2020-03-02          Carrstad
# 249   9533.0        Matthew Hall   2024-05-23  North Carrieport
#
# [250 rows x 4 columns]

# %%
# Writing DataFrame to CSV
df.to_csv('employees.csv', index=False)

# Reading DataFrame from CSV
df_from_csv = pd.read_csv('employees.csv')
print(df_from_csv.head())
# Out:
#      empid             empname joining_date      empcity  id
# 0  unknowm             unknowm      unknowm      unknowm NaN
# 1   2957.0      Brianna Jordan   2023-10-09   Pamelafort NaN
# 2   2116.0  Rebecca Montgomery   2020-03-31  Johnnyville NaN
# 3   2577.0     Judith Mitchell   2021-02-09    Ochoaview NaN
# 4   6632.0           Mary Love   2020-11-13  New Jessica NaN

# %%
df["Experience"]=np.random.randint(0,1,size=num_rows)

# %%
df
# Out:
#        empid             empname joining_date           empcity  id  \
# 0    unknowm             unknowm      unknowm           unknowm NaN
# 1     2957.0      Brianna Jordan   2023-10-09        Pamelafort NaN
# 2     2116.0  Rebecca Montgomery   2020-03-31       Johnnyville NaN
# 3     2577.0     Judith Mitchell   2021-02-09         Ochoaview NaN
# 4     6632.0           Mary Love   2020-11-13       New Jessica NaN
# ..       ...                 ...          ...               ...  ..
# 245   9433.0        David Campos   2022-04-24  Rodriguezborough NaN
# 246   2787.0        Derek Jarvis   2024-04-27        Laurietown NaN
# 247  unknowm             unknowm      unknowm           unknowm NaN
# 248   5223.0         Patty Greer   2020-03-02          Carrstad NaN
# 249   9533.0        Matthew Hall   2024-05-23  North Carrieport NaN
#
#      Experience
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ..          ...
# 245           0
# 246           0
# 247           0
# 248           0
# 249           0
#
# [250 rows x 6 columns]

# %%
df1=df[df["Experience"]==0]

# %%
df1
# Out:
#        empid             empname joining_date           empcity  id  \
# 0    unknowm             unknowm      unknowm           unknowm NaN
# 1     2957.0      Brianna Jordan   2023-10-09        Pamelafort NaN
# 2     2116.0  Rebecca Montgomery   2020-03-31       Johnnyville NaN
# 3     2577.0     Judith Mitchell   2021-02-09         Ochoaview NaN
# 4     6632.0           Mary Love   2020-11-13       New Jessica NaN
# ..       ...                 ...          ...               ...  ..
# 245   9433.0        David Campos   2022-04-24  Rodriguezborough NaN
# 246   2787.0        Derek Jarvis   2024-04-27        Laurietown NaN
# 247  unknowm             unknowm      unknowm           unknowm NaN
# 248   5223.0         Patty Greer   2020-03-02          Carrstad NaN
# 249   9533.0        Matthew Hall   2024-05-23  North Carrieport NaN
#
#      Experience
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ..          ...
# 245           0
# 246           0
# 247           0
# 248           0
# 249           0
#
# [250 rows x 6 columns]

# %%
df.drop("Experience",axis=1)
# Out:
#        empid             empname joining_date           empcity  id
# 0    unknowm             unknowm      unknowm           unknowm NaN
# 1     2957.0      Brianna Jordan   2023-10-09        Pamelafort NaN
# 2     2116.0  Rebecca Montgomery   2020-03-31       Johnnyville NaN
# 3     2577.0     Judith Mitchell   2021-02-09         Ochoaview NaN
# 4     6632.0           Mary Love   2020-11-13       New Jessica NaN
# ..       ...                 ...          ...               ...  ..
# 245   9433.0        David Campos   2022-04-24  Rodriguezborough NaN
# 246   2787.0        Derek Jarvis   2024-04-27        Laurietown NaN
# 247  unknowm             unknowm      unknowm           unknowm NaN
# 248   5223.0         Patty Greer   2020-03-02          Carrstad NaN
# 249   9533.0        Matthew Hall   2024-05-23  North Carrieport NaN
#
# [250 rows x 5 columns]

# %%
df["Experience"]=np.random.randint(2,3,size=num_rows)

# %%
df
# Out:
#        empid             empname joining_date           empcity  id  \
# 0    unknowm             unknowm      unknowm           unknowm NaN
# 1     2957.0      Brianna Jordan   2023-10-09        Pamelafort NaN
# 2     2116.0  Rebecca Montgomery   2020-03-31       Johnnyville NaN
# 3     2577.0     Judith Mitchell   2021-02-09         Ochoaview NaN
# 4     6632.0           Mary Love   2020-11-13       New Jessica NaN
# ..       ...                 ...          ...               ...  ..
# 245   9433.0        David Campos   2022-04-24  Rodriguezborough NaN
# 246   2787.0        Derek Jarvis   2024-04-27        Laurietown NaN
# 247  unknowm             unknowm      unknowm           unknowm NaN
# 248   5223.0         Patty Greer   2020-03-02          Carrstad NaN
# 249   9533.0        Matthew Hall   2024-05-23  North Carrieport NaN
#
#      Experience
# 0             2
# 1             2
# 2             2
# 3             2
# 4             2
# ..          ...
# 245           2
# 246           2
# 247           2
# 248           2
# 249           2
#
# [250 rows x 6 columns]

# %%
df1=df[df["Experience"]==3]

# %%
df1
# Out:
# Empty DataFrame
# Columns: [empid, empname, joining_date, empcity, id, Experience]
# Index: []
