# %%
import pandas as pd

# %%
df = pd.DataFrame({'Name': ['Alice', 'Bob', 'Aritra'],
                   'Age': [25, 30, 35],
                   'Location': ['Seattle', 'New York', 'Kona']},
                  index=([10, 20, 30]))
df.index
df
# Out:
#       Name  Age  Location
# 10   Alice   25   Seattle
# 20     Bob   30  New York
# 30  Aritra   35      Kona

# %%
df=pd.DataFrame({"Name" :["Omkar","Sharad","Vilas","Atharav","Varad"],
                 "City" :["Mumbai","Pune","Aurangabad","Kochi","Indore"]},
                index=[1,2,3,4,5])
df
# Out:
#       Name        City
# 1    Omkar      Mumbai
# 2   Sharad        Pune
# 3    Vilas  Aurangabad
# 4  Atharav       Kochi
# 5    Varad      Indore

# %%
df.head(3)
# Out:
#      Name        City
# 1   Omkar      Mumbai
# 2  Sharad        Pune
# 3   Vilas  Aurangabad

# %%
df["Name"]
# Out:
# 1      Omkar
# 2     Sharad
# 3      Vilas
# 4    Atharav
# 5      Varad
# Name: Name, dtype: object

# %%
a=[1,2,3,4]
a=pd.Series(a,index=["a","b","c","d"])
print(a)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
print(a[1])
# Out:
# 2

# %%
print(a["a"])
# Out:
# 1

# %%
print(a["b"])
# Out:
# 2

# %%
df=pd.Series({"Day1":4200,"Day2":"3400","Day3":2389})
print(df)
# Out:
# Day1    4200
# Day2    3400
# Day3    2389
# dtype: object

# %%
df=pd.DataFrame({"Days":[1,2,3,4],
                "Calorie":[3200,2100,4500,2300]})
print(df)
# Out:
#    Days  Calorie
# 0     1     3200
# 1     2     2100
# 2     3     4500
# 3     4     2300

# %%
df=pd.read_csv("data_science_job.csv")

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df.isna().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index     479
# gender                    4508
# relevent_experience          0
# enrolled_university        386
# education_level            460
# major_discipline          2813
# experience                  65
# company_size              5938
# company_type              6140
# training_hours             766
# target                       0
# dtype: int64

# %%
df["city_development_index"].isna().sum()
# Out:
# 479

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# enrollee_id               0
# city                      0
# city_development_index    0
# gender                    0
# relevent_experience       0
# enrolled_university       0
# education_level           0
# major_discipline          0
# experience                0
# company_size              0
# company_type              0
# training_hours            0
# target                    0
# dtype: int64

# %%
df=pd.read_csv("data_science_job.csv")

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline  experience company_size    company_type  training_hours  \
# 0             STEM        20.0          NaN             NaN            36.0
# 1             STEM        15.0        50-99         Pvt Ltd            47.0
# ...

# %%
df.isna().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index     479
# gender                    4508
# relevent_experience          0
# enrolled_university        386
# education_level            460
# major_discipline          2813
# experience                  65
# company_size              5938
# company_type              6140
# training_hours             766
# target                       0
# dtype: int64

# %%
df["city_development_index"].dtype
# Out:
# dtype('float64')

# %%
a=df["city_development_index"].mean()
df["city_development_index"].fillna(a,inplace=True)

# %%
df["city_development_index"].isna().sum()
# Out:
# 0

# %%
df["gender"]
# Out:
# 0        Male
# 1        Male
# 2         NaN
# 3         NaN
# 4        Male
#          ...
# 19153    Male
# 19154    Male
# 19155    Male
# 19156    Male
# 19157     NaN
# Name: gender, Length: 19158, dtype: object

# %%
df.columns
# Out:
# Index(['enrollee_id', 'city', 'city_development_index', 'gender',
#        'relevent_experience', 'enrolled_university', 'education_level',
#        'major_discipline', 'experience', 'company_size', 'company_type',
#        'training_hours', 'target'],
#       dtype='object')

# %%
a= pd.DataFrame({'float': [1.0],
                   'int': [1],
                   'datetime': [pd.Timestamp('20180310')],
                   'string': ['foo']})
a.columns
# Out:
# Index(['float', 'int', 'datetime', 'string'], dtype='object')

# %%
df.dtypes
# Out:
# enrollee_id                 int64
# city                       object
# city_development_index    float64
# gender                     object
# relevent_experience        object
# enrolled_university        object
# education_level            object
# major_discipline           object
# experience                float64
# company_size               object
# company_type               object
# training_hours            float64
# target                    float64
# dtype: object

# %%
a.dtypes
# Out:
# float              float64
# int                  int64
# datetime    datetime64[ns]
# string              object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  float64
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  training_hours          18392 non-null  float64
#  12  target                  19158 non-null  float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 1.9+ MB

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   float     1 non-null      float64
#  1   int       1 non-null      int64
#  2   datetime  1 non-null      datetime64[ns]
#  3   string    1 non-null      object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 164.0+ bytes

# %%
a.select_dtypes(include="int64")
# Out:
#    int
# 0    1

# %%
df.dtypes
# Out:
# enrollee_id                 int64
# city                       object
# city_development_index    float64
# gender                     object
# relevent_experience        object
# enrolled_university        object
# education_level            object
# major_discipline           object
# experience                float64
# company_size               object
# company_type               object
# training_hours            float64
# target                    float64
# dtype: object

# %%
df.select_dtypes(include="int64")
# Out:
#        enrollee_id
# 0             8949
# 1            29725
# 2            11561
# 3            33241
# 4              666
# ...            ...
# 19153         7386
# 19154        31398
# 19155        24576
# 19156         5756
# 19157        23834
#
# [19158 rows x 1 columns]

# %%
df.values
# Out:
# array([[8949, 'city_103', 0.92, ..., nan, 36.0, 1.0],
#        [29725, 'city_40', 0.7759999999999999, ..., 'Pvt Ltd', 47.0, 0.0],
#        [11561, 'city_21', 0.624, ..., nan, 83.0, 0.0],
#        ...,
#        [24576, 'city_103', 0.92, ..., 'Pvt Ltd', 44.0, 0.0],
#        [5756, 'city_65', 0.802, ..., 'Pvt Ltd', 97.0, 0.0],
#        [23834, 'city_67', 0.855, ..., nan, 127.0, 0.0]], dtype=object)

# %%
a.values
# Out:
# array([[1.0, 1, Timestamp('2018-03-10 00:00:00'), 'foo']], dtype=object)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=19158, step=1)

# %%
a.index
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
b= pd.DataFrame({'age':    [ 3,  29],
                   'height': [94, 170],
                   'weight': [31, 115]})

# %%
b.values
# Out:
# array([[  3,  94,  31],
#        [ 29, 170, 115]], dtype=int64)

# %%
b.index
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
c = pd.DataFrame([[1, 2], [4, 5], [7, 8]],
                  index=['cobra', 'viper', 'sidewinder'],
                  columns=['max_speed', 'shield'])

# %%
c
# Out:
#             max_speed  shield
# cobra               1       2
# viper               4       5
# sidewinder          7       8

# %%
c.loc["cobra"]
# Out:
# max_speed    1
# shield       2
# Name: cobra, dtype: int64

# %%
c.loc[c["shield"]>3]
# Out:
#             max_speed  shield
# viper               4       5
# sidewinder          7       8

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df.loc[df["experience"]==20]
# Out:
#        enrollee_id      city  city_development_index  gender  \
# 0             8949  city_103                   0.920    Male
# 4              666  city_162                   0.767    Male
# 12           25619   city_61                   0.913    Male
# 30           14928  city_103                   0.920    Male
# 33           26966  city_160                   0.920  Female
# ...            ...       ...                     ...     ...
# 19117         3458  city_114                   0.926    Male
# 19121         1940   city_10                   0.895    Male
# 19128         3365   city_16                   0.910     NaN
# 19143        33047  city_103                   0.920    Male
# 19155        24576  city_103                   0.920    Male
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 4      Has relevent experience       no_enrollment         Masters
# ...

# %%
df.loc[df["experience"]>15]
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 4              666  city_162                   0.767   Male
# 9              699  city_103                   0.920    NaN
# 12           25619   city_61                   0.913   Male
# 15            6588  city_114                   0.926   Male
# ...            ...       ...                     ...    ...
# 19128         3365   city_16                   0.910    NaN
# 19133        25191   city_10                   0.895  Other
# 19141         7782   city_23                   0.899   Male
# 19143        33047  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 4      Has relevent experience       no_enrollment         Masters
# ...

# %%
df.loc[df(["experience"] == 10) &(df["gender"]=="Male")]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 df.loc[df(["experience"] == 10) &(df["gender"]=="Male")]
#
# TypeError: 'DataFrame' object is not callable

# %%
c.loc[(c['max_speed'] > 1) & (c['shield'] < 8)]
# Out:
#        max_speed  shield
# viper          4       5

# %%
df.loc[(df["experience"]>10)& (df["gender"]=="Male")]
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 4              666  city_162                   0.767   Male
# 7              402   city_46                   0.762   Male
# 12           25619   city_61                   0.913   Male
# ...            ...       ...                     ...    ...
# 19141         7782   city_23                   0.899   Male
# 19143        33047  city_103                   0.920   Male
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
c.loc[(c['max_speed'] > 4) | (c['shield'] < 5)]
# Out:
#             max_speed  shield
# cobra               1       2
# sidewinder          7       8

# %%
c.loc[['viper', 'sidewinder'], ['shield']] = 50

# %%
c
# Out:
#             max_speed  shield
# cobra               1       2
# viper               4      50
# sidewinder          7      50

# %%
b
# Out:
#    age  height  weight
# 0    3      94      31
# 1   29     170     115

# %%
b.loc[[0,1],["Weight"]]=45

# %%
b
# Out:
#    age  height  weight  Weight
# 0    3      94      31    45.0
# 1   29     170     115    45.0

# %%
# Out:
#         age  height  weight  Weight
# 0         3      94      31    45.0
# 1        29     170     115    45.0
# height  175     175     175   175.0

# %%
b
# Out:
#    age  height  weight
# 0    3      94      31
# 1   29     170     115

# %%
b.loc[:,"height"]=165

# %%
b
# Out:
#    age  height  weight
# 0    3     165      31
# 1   29     165     115

# %%
c.loc[c['shield'] > 35] = 0

# %%
c
# Out:
#             max_speed  shield
# cobra               1       2
# viper               0       0
# sidewinder          0       0

# %%
c.loc["viper", "shield"] += 5
c
# Out:
#             max_speed  shield
# cobra               1       2
# viper               0      10
# sidewinder          0       0

# %%
c = pd.DataFrame([[1, 2], [4, 5], [7, 8]],
                  index=[7, 8, 9], columns=['max_speed', 'shield'])
c
# Out:
#    max_speed  shield
# 7          1       2
# 8          4       5
# 9          7       8
